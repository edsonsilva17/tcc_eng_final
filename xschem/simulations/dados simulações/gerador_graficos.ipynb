# %%
print('Gerando Gráficos')
# Out:
# Gerando Gráficos

# %%
import pandas as pd

diodo18 = pd.read_csv("diodo18.csv")
print(diodo18)
# Out:
#                      tensao corrente
# 0    -1.80000000e+00 -4.08259950e-08
# 1    -1.79000000e+00 -4.06188576e-08
# 2    -1.78000000e+00 -4.04116918e-08
# 3    -1.77000000e+00 -4.02045259e-08
# 4    -1.76000000e+00 -3.99973885e-08
# ..                                ...
# 356   1.76000000e+00  2.88000572e-02
# 357   1.77000000e+00  2.91904110e-02
# 358   1.78000000e+00  2.95810097e-02
# 359   1.79000000e+00  2.99718319e-02
# 360   1.80000000e+00  3.03628568e-02
#
# [361 rows x 1 columns]

# %%
import csv

with open('diodo18.csv', 'r') as arquivo:
    arquivo_csv = csv.reader(arquivo, delimiter=' ')
    for linha in arquivo_csv:
        while '' in linha:
            linha.remove('')
        print(linha)
# Out:
# ['tensao', 'corrente']
# ['-1.80000000e+00', '-4.08259950e-08']
# ['-1.79000000e+00', '-4.06188576e-08']
# ['-1.78000000e+00', '-4.04116918e-08']
# ['-1.77000000e+00', '-4.02045259e-08']
# ['-1.76000000e+00', '-3.99973885e-08']
# ['-1.75000000e+00', '-3.97902227e-08']
# ['-1.74000000e+00', '-3.95830853e-08']
# ['-1.73000000e+00', '-3.93759194e-08']
# ['-1.72000000e+00', '-3.91687536e-08']
# ['-1.71000000e+00', '-3.89616730e-08']
# ['-1.70000000e+00', '-3.87545072e-08']
# ['-1.69000000e+00', '-3.85473982e-08']
# ['-1.68000000e+00', '-3.83402607e-08']
# ['-1.67000000e+00', '-3.81331517e-08']
# ['-1.66000000e+00', '-3.79260143e-08']
# ['-1.65000000e+00', '-3.77189053e-08']
# ['-1.64000000e+00', '-3.75117963e-08']
# ['-1.63000000e+00', '-3.73046589e-08']
# ['-1.62000000e+00', '-3.70975499e-08']
# ['-1.61000000e+00', '-3.68904693e-08']
# ['-1.60000000e+00', '-3.66833319e-08']
# ['-1.59000000e+00', '-3.64762514e-08']
# ['-1.58000000e+00', '-3.62691708e-08']
# ...
