# %%
import csv
import matplotlib.pyplot as plt
x1 = list()
y1 = list()
x2 = list()
y2 = list()

#Abrindo dados PMOS 1.8 LVT
with open('diodo18lvt.csv', 'r') as arquivo:
    arquivo_csv = csv.reader(arquivo, delimiter=' ')
    for linha in arquivo_csv:
        while '' in linha:
            linha.remove('')
        x1.append(float(linha[0]))
        y1.append(float(linha[1]))

#Abrindo dados PMOS 1.8
with open('diodo18.csv', 'r') as arquivo:
    arquivo_csv = csv.reader(arquivo, delimiter=' ')
    for linha in arquivo_csv:
        while '' in linha:
            linha.remove('')
        x2.append(float(linha[0]))
        y2.append(float(linha[1]))

#Plotando Gráficos
plt.plot(x1,y1, lw=2., label='PMOS 1.8 LVT')
plt.plot(x2,y2, lw=2., label='PMOS 1.8')
#plt.ylim(0, 10)
plt.xlim(-2, 2)
plt.title('Curva caracteística - Mosfet funcionando como Diodo')
plt.xlabel('Tensão (V)')
plt.ylabel('Corrente (A)')
plt.legend()
plt.grid()
plt.savefig('curva_diodo.png', format='png')
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

x1 = list()
y1 = list()
x2 = list()
y2 = list()
x3 = list()
y3 = list()
#Abrindo dados ret 1
with open('ret1.csv', 'r') as arquivo:
    arquivo_csv = csv.reader(arquivo, delimiter=' ')
    for linha in arquivo_csv:
        while '' in linha:
            linha.remove('')
        x1.append(float(linha[0])*(10**6))
        y1.append(float(linha[1]))

#Abrindo dados ret 3
with open('ret3.csv', 'r') as arquivo:
    arquivo_csv = csv.reader(arquivo, delimiter=' ')
    for linha in arquivo_csv:
        while '' in linha:
            linha.remove('')
        x2.append(float(linha[0])*(10**6))
        y2.append(float(linha[1]))

#Abrindo dados ret 8
with open('ret8.csv', 'r') as arquivo:
    arquivo_csv = csv.reader(arquivo, delimiter=' ')
    for linha in arquivo_csv:
        while '' in linha:
            linha.remove('')
        x3.append(float(linha[0])*(10**6))
        y3.append(float(linha[1]))

#Plotando Gráficos
fig, axs = plt.subplots(1, 3, figsize=(16,4), dpi=300)
axs[0].plot(x1, y1, 'tab:red')
axs[0].set_title('1 Célula')
axs[1].plot(x2, y2, 'tab:blue')
axs[1].set_title('3 Células')
axs[2].plot(x3, y3, 'tab:green')
axs[2].set_title('8 Células')


for ax in axs.flat:
    ax.set(xlabel='Tempo (\u00B5s)', ylabel='Tensão (V)')
    ax.grid()


#for ax in axs.flat:
#    ax.label_outer()

plt.savefig('ret.png', format='png')
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
x1 = list()
y1 = list()
x2 = list()
y2 = list()
x3 = list()
y3 = list()

#Abrindo dados Entrada Comparador
with open('ota_in.csv', 'r') as arquivo:
    arquivo_csv = csv.reader(arquivo, delimiter=' ')
    for linha in arquivo_csv:
        while '' in linha:
            linha.remove('')
        x1.append(float(linha[0]))
        y1.append(float(linha[1]))

#Abrindo dados Saída Comparador
with open('ota_out.csv', 'r') as arquivo:
    arquivo_csv = csv.reader(arquivo, delimiter=' ')
    for linha in arquivo_csv:
        while '' in linha:
            linha.remove('')
        x2.append(float(linha[0]))
        y2.append(float(linha[1]))
        
#Abrindo dados Referência do Comparador
with open('ota_ref.csv', 'r') as arquivo:
    arquivo_csv = csv.reader(arquivo, delimiter=' ')
    for linha in arquivo_csv:
        while '' in linha:
            linha.remove('')
        x3.append(float(linha[0]))
        y3.append(float(linha[1]))

#Plotando Gráficos
plt.plot(x1,y1, lw=2., label='Tensão de Entrada')
plt.plot(x2,y2, lw=2., label='Tensão de Saída')
plt.plot(x3,y3, lw=2., label='Tensão de Referência')
plt.xlim(0, 2)
plt.title('OTA como comparador')
plt.xlabel('Tensão de Entrada (V)')
plt.ylabel('Tensão (V)')
plt.legend()
plt.grid()
plt.savefig('comparador.png', format='png')
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
x1 = [[], [], [], [], [], []]
y1 = [[], [], [], [], [], []]
x2 = [[], [], [], [], [], []]
y2 = [[], [], [], [], [], []]

#Abrindo dados nmos 3.3
with open('tb_ldo.csv', 'r') as arquivo:
    arquivo_csv = csv.reader(arquivo, delimiter=' ')
    for linha in arquivo_csv:
        while '' in linha:
            linha.remove('')
        if float(linha[3]) == 0.8:
            x1[0].append(float(linha[0]))
            y1[0].append(float(linha[1]))
        if float(linha[3]) == 1.0:
            x1[1].append(float(linha[0]))
            y1[1].append(float(linha[1]))
        if float(linha[3]) == 1.2:
            x1[2].append(float(linha[0]))
            y1[2].append(float(linha[1]))
        if float(linha[3]) == 1.4:
            x1[3].append(float(linha[0]))
            y1[3].append(float(linha[1]))
        if float(linha[3]) == 1.6:
            x1[4].append(float(linha[0]))
            y1[4].append(float(linha[1]))
        if float(linha[3]) == 1.8:
            x1[5].append(float(linha[0]))
            y1[5].append(float(linha[1]))

#Abrindo dados nmos 1.8 lvt
with open('ldo_lvt.csv', 'r') as arquivo:
    arquivo_csv = csv.reader(arquivo, delimiter=' ')
    for linha in arquivo_csv:
        while '' in linha:
            linha.remove('')
        if float(linha[3]) == 0.8:
            x2[0].append(float(linha[0]))
            y2[0].append(float(linha[1]))
        if float(linha[3]) == 1.0:
            x2[1].append(float(linha[0]))
            y2[1].append(float(linha[1]))
        if float(linha[3]) == 1.2:
            x2[2].append(float(linha[0]))
            y2[2].append(float(linha[1]))
        if float(linha[3]) == 1.4:
            x2[3].append(float(linha[0]))
            y2[3].append(float(linha[1]))
        if float(linha[3]) == 1.6:
            x2[4].append(float(linha[0]))
            y2[4].append(float(linha[1]))
        if float(linha[3]) == 1.8:
            x2[5].append(float(linha[0]))
            y2[5].append(float(linha[1]))

fig, axs = plt.subplots(1, 2, figsize=(10,4), dpi=300)

axs[0].plot(x1[0],y1[0], lw=2., label='Vref = 0.8')
axs[0].plot(x1[1],y1[1], lw=2., label='Vref = 1.0')
axs[0].plot(x1[2],y1[2], lw=2., label='Vref = 1.2')
axs[0].plot(x1[3],y1[3], lw=2., label='Vref = 1.4')
axs[0].plot(x1[4],y1[4], lw=2., label='Vref = 1.6')
axs[0].plot(x1[5],y1[5], lw=2., label='Vref = 1.8')
axs[0].set_title('Nmos 3.3V nvt')

axs[1].plot(x2[0],y2[0], lw=2., label='Vref = 0.8')
axs[1].plot(x2[1],y2[1], lw=2., label='Vref = 1.0')
axs[1].plot(x2[2],y2[2], lw=2., label='Vref = 1.2')
axs[1].plot(x2[3],y2[3], lw=2., label='Vref = 1.4')
axs[1].plot(x2[4],y2[4], lw=2., label='Vref = 1.6')
axs[1].plot(x2[5],y2[5], lw=2., label='Vref = 1.8')
axs[1].set_title('Nmos 1.8V lvt')


for ax in axs.flat:
    ax.set(xlabel='Tensão de Entrada (V)', ylabel='Tensão de Saída (V)')
    #ax.xlim(0, 5.1)
    #ax.ylim(0, 2)
    ax.legend()
    ax.grid()


#Plotando Gráficos

plt.savefig('ldo.png', format='png')
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
x1 = list()
y1 = list()
x2 = list()
y2 = list()

#Abrindo dados prelayout ideal
with open('prelayout_ideal.csv', 'r') as arquivo:
    arquivo_csv = csv.reader(arquivo, delimiter=' ')
    for linha in arquivo_csv:
        while '' in linha:
            linha.remove('')
        x1.append(float(linha[0])*(10**6))
        y1.append(float(linha[1]))

#Abrindo dados poslayout ideal
with open('poslayout_ideal.csv', 'r') as arquivo:
    arquivo_csv = csv.reader(arquivo, delimiter=' ')
    for linha in arquivo_csv:
        while '' in linha:
            linha.remove('')
        x2.append(float(linha[0])*(10**6))
        y2.append(float(linha[1]))

#Plotando Gráficos
plt.plot(x1,y1, lw=2., label='$\mathit{Pré}$-$\mathit{layout}$')
plt.plot(x2,y2, lw=2., label='$\mathit{Pós}$-$\mathit{layout}$')
plt.xlim(0, 30)
plt.ylim(0, 2)
plt.title('Simulação com fonte ideal')
plt.xlabel('Tempo (\u00B5s)')
plt.ylabel('Tensão (V)')
plt.legend()
plt.grid()
plt.savefig('fontesideais_ideal.png', format='png')
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
x1 = list()
y1 = list()
x2 = list()
y2 = list()

#Abrindo dados prelayout ideal
with open('prelayout_casamento.csv', 'r') as arquivo:
    arquivo_csv = csv.reader(arquivo, delimiter=' ')
    for linha in arquivo_csv:
        while '' in linha:
            linha.remove('')
        x1.append(float(linha[0])*(10**6))
        y1.append(float(linha[1]))

#Abrindo dados poslayout ideal
with open('poslayout_casamento.csv', 'r') as arquivo:
    arquivo_csv = csv.reader(arquivo, delimiter=' ')
    for linha in arquivo_csv:
        while '' in linha:
            linha.remove('')
        x2.append(float(linha[0])*(10**6))
        y2.append(float(linha[1]))

#Plotando Gráficos
plt.plot(x1,y1, lw=2., label='$\mathit{Pré}$-$\mathit{layout}$')
plt.plot(x2,y2, lw=2., label='$\mathit{Pós}$-$\mathit{layout}$')
plt.xlim(0, 40)
plt.ylim(0, 2)
plt.title('Simulação com casamento de impedâncias')
plt.xlabel('Tempo (\u00B5s)')
plt.ylabel('Tensão (V)')
plt.legend()
plt.grid()
plt.savefig('fontes_casamento.png', format='png')
plt.show()
